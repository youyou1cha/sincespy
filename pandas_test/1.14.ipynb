# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
s = pd.Series(np.random.randn(10).cumsum(),index=np.arange(0,100,10))

# %%
s
# Out:
# 0     1.486007
# 10    2.014772
# 20    0.335751
# 30    0.745066
# 40    2.394595
# 50    4.857969
# 60    5.780020
# 70    5.840016
# 80    5.558101
# 90    6.003727
# dtype: float64

# %%
s.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(10,4).cumsum(0),columns=['A','B','C','D'],index=np.arange(0,100,10))

# %%
df
# Out:
#            A         B         C         D
# 0  -1.138815 -0.093940  0.274938 -0.088902
# 10 -2.593890 -1.438322  0.227522 -0.830811
# 20 -0.523190 -1.995081 -0.077644  1.074920
# 30  0.530233 -0.169226  0.230261  1.409260
# 40  0.405403 -0.629236 -1.188608  0.062486
# 50  1.063272 -1.731972 -1.372474 -0.324470
# 60  1.403587 -2.824719  0.024409 -2.559736
# 70  2.299182 -3.373470 -1.746207 -1.372800
# 80  2.086428 -4.047729 -1.629652 -1.812767
# 90  1.610980 -3.696240 -3.936813 -1.071875

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
fig,axes = plt.subplots(2,1)

# %%
data = pd.Series(np.random.rand(16),index=list('abcdefghijklmnop'))

# %%
data.plot.bar(ax=axes[0],color='k',alpha=0.7)
# Out:
# <AxesSubplot:>

# %%
data.plot.barh(ax=axes[1],color='k',alpha=0.7)
# Out:
# <AxesSubplot:>
